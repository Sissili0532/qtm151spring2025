# %% [markdown]
# # <span style="color:darkblue"> QTM 151 - Quiz 2 </span>

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size="5">
#
# Print your name below

# %%
# Write your answer here

print("Sissi Li")
# Out:
# Sissi Li

# %% [markdown]
# <font size = "5" >
# This quiz is open book
#
# - You can use the lecture notes
# - You will get partial credit for attempting the questions
# - To get full credit, the code should run as intended
# - You should <span style="color:red"> NOT </span> communicate with other students
#
# Print the following message: <br>
#
# "I will abide by Emory's code of conduct"

# %%
# Write your answer here:

print("I will abide by Emory's code of conduct")
# Out:
# I will abide by Emory's code of conduct

# %% [markdown]
# <font size = "5">
#
# Import the libraries "numpy", "matplotlib.pyplot", <br>
# "pandas", "statsmodels.api" and "statsmodels.formula.api"

# %%
# Write your answer here

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %% [markdown]
# <font size = "5">
#
# Read the dataset "data_quiz/fifa23_players_basic.csv"
#
# - It's a dataset on professional soccer players
# - Rows correspond to players (18,539)
# - Columns contain attributes of players (32)
# - Try to view the dataset before starting <br>
# to get a sense of its content

# %%
# Write your own code

df = pd.read_csv("data_quiz/fifa23_players_basic.csv")

# %% [markdown]
# <font size = "5">
#
# (a) Use queries
#
# <font size = "3">
#
# - Browse the dataset and search for the height variable in cm (centimeters).
#
# - Subset the players whose value of the height variable is above 175 <br>
# and store it in a new dataset
# - How many players are above this height threshold?
#
# HINT: Remember that there is a special syntax for <br>
# when the column names have spaces (see Lecture 10) <br>
# and when the value is a string. See example provided.

# %%
# Write your own code

# Example: The following code filters whether 
# observations for which `On Loan` is equal to yes
# dataset.query(' `On Loan` == "YES" ')
# Note: be careful with using backward quotations ` here.
# Now apply this to your own example, and calculate the total number of observations.


highest_value = max(df["Height(in cm)"])
print(highest_value)

height_above_75_players = df.query("`Height(in cm)` > 175")
num = len(height_above_75_players)
print(num)
# Out:
# 206
# 14653

# %% [markdown]
# <font size = "5">
#
# (b) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# The varable "Contract Until" shows the date in which a player's contract will expire.
# - Use ".sort_values()" to order the "Contract Until" column <br>
# from later dates to earlier dates.
# - Get a subset with the 5 players in the dataset <br>
# whose contracts will expire later.
# - From this subset, display the names and year in which the contract will expire.
#
# Your output should look something like this:
#
# | Full Name | Contract Until |
# | -------- | ------- |
# | José Luis García Vayá | 2032
# | José Luis García Vayá | 2032
# | Jon Moncayola Tollar | 2031
# | Jon Moncayloa Tollar | 2031
# | Josip Sutalo | 2028
# | Aurelien Tchouaméni | 2028

# %%
# Write your own code

df_sorted = df.sort_values(by="Contract Until", ascending=False)  

later_contract_players = df_sorted.iloc[:5]  

print(later_contract_players[["Full Name", "Contract Until"]])
# Out:
#                   Full Name Contract Until
# 1876  Jose Luís García Vayá           2032
# 1806  Jose Luís García Vayá           2032
# 1478   Jon Moncayola Tollar           2031
# 1523   Jon Moncayola Tollar           2031
# 1649           Josip Šutalo           2028

# %% [markdown]
# <font size = "5">
#
# (c) Create a function and apply it to a column <br>
#
# <font size = "3">
#
# Step 1:
# - Define a function with a parameter "TotalStats"
# - If "TotalStats > 85", classification = "Top Performer"
# - If "TotalStats <= 85", classification = "Non Top-Performer"
# - The function returns "classification"
#
# Step 2:
# - Extract the column "TotalStats" in the dataset <br>
# - Create a new variable called "player_classification" <br>
# to assign each player to the correct classification
#
# HINT: Use the ".apply()" function

# %%
# Write your own code

def classify_player(TotalStats):
    if TotalStats > 85:
        return "Top Performer"
    else:
        return "Non Top-Performer"

df["player_classification"] = df["TotalStats"].apply(classify_player)

print(df["player_classification"])
# Out:
# 0        Top Performer
# 1        Top Performer
# 2        Top Performer
# 3        Top Performer
# 4        Top Performer
#              ...
# 18534    Top Performer
# 18535    Top Performer
# 18536    Top Performer
# 18537    Top Performer
# 18538    Top Performer
# Name: player_classification, Length: 18539, dtype: object

# %% [markdown]
# <font size = "5">
#
# (d) Regression function
#
# <font size = "3">
#
# - Run a regression of "Overall" (left-hand side) on "Age" (right-hand side)
# - What are the values of the coefficients?
#
# [HINT: Use the commands ```smf.ols()``` and ```.fit()``` and ```.params``` <br>
# from Lecture 11 ]

# %%
# Write your own code

model = smf.ols(formula = "Overall ~ Age", data=df).fit()  
coefficients = model.params  

print(coefficients)
# Out:
# Intercept    49.787345
# Age           0.636467
# dtype: float64

# %% [markdown]
# <font size = "5">
#
# (e) Split a dataset into subsets
#
# <font size = "3">
#
# - Store the total number of rows of the dataset in a variable called ```n``` <br>
# - Create a new variable called ```random_var``` drawn from a <br>
# uniform distribution between 0 and 1 with size ```n```
# - Use .query() to subset all observations with ```random_var <0.4```.<br>
# store it in a new dataset called "data0"
# - Use .query() to subset all observations with ```random_var >= 0.4```.<br>
# store it in a new dataset called "data1"
#
# [HINT: See Lecture 2 for how to generate a uniform random variable]

# %%
# Write your own code

n = len(df) 

df["random_var"] = np.random.uniform(0, 1, size=n)  

data0 = df.query("random_var < 0.4")  
data1 = df.query("random_var >= 0.4") 

print(data0)
print(data1)
# Out:
#        Unnamed: 0         Known As           Full Name  Overall  Potential  \
# 0               0         L. Messi        Lionel Messi       91         91
# 3               3     K. De Bruyne     Kevin De Bruyne       91         91
# 4               4        K. Mbappé       Kylian Mbappé       91         95
# 5               5         M. Salah       Mohamed Salah       90         90
# 6               6      T. Courtois    Thibaut Courtois       90         91
# ...           ...              ...                 ...      ...        ...
# 18524       18524       A. Brînzea      Andreș Brînzea       48         72
# 18525       18525  J. Russell-Rowe  Jacen Russell-Rowe       48         65
# 18530       18530           S. Bag           Sajal Bag       48         61
# 18532       18532         H. Singh   Harmanpreet Singh       48         56
# 18535       18535     Yang Dejiang        Dejiang Yang       47         57
#
#        Value(in Euro) Positions Played Best Position Nationality  \
# 0            54000000               RW           CAM   Argentina
# 3           107500000           CM,CAM            CM     Belgium
# 4           190500000            ST,LW            ST      France
# 5           115500000               RW            RW       Egypt
# 6            90000000               GK            GK     Belgium
# ...               ...              ...           ...         ...
# 18524          130000               GK            GK     Romania
# 18525          120000               ST           CAM      Canada
# 18530          110000            CM,RM            RM       India
# 18532          100000               ST            ST       India
# 18535           90000              CDM           CDM    China PR
#
#                                              Image Link  ...  Skill Moves  \
# 0      https://cdn.sofifa.net/players/158/023/23_60.png  ...            4
# 3      https://cdn.sofifa.net/players/192/985/23_60.png  ...            4
# 4      https://cdn.sofifa.net/players/231/747/23_60.png  ...            5
# 5      https://cdn.sofifa.net/players/209/331/23_60.png  ...            4
# 6      https://cdn.sofifa.net/players/192/119/23_60.png  ...            1
# ...                                                 ...  ...          ...
# 18524  https://cdn.sofifa.net/players/271/179/23_60.png  ...            1
# 18525  https://cdn.sofifa.net/players/269/923/23_60.png  ...            2
# 18530  https://cdn.sofifa.net/players/270/739/23_60.png  ...            2
# 18532  https://cdn.sofifa.net/players/259/745/23_60.png  ...            2
# 18535  https://cdn.sofifa.net/players/261/933/23_60.png  ...            2
#
#        International Reputation  National Team Name  \
# 0                             5           Argentina
# 3                             4             Belgium
# 4                             4              France
# 5                             4                   -
# 6                             4             Belgium
# ...                         ...                 ...
# 18524                         1                   -
# 18525                         1                   -
# 18530                         1                   -
# 18532                         1                   -
# 18535                         1                   -
#
#                   National Team Image Link  National Team Position  \
# 0      https://cdn.sofifa.net/flags/ar.png                      RW
# 3      https://cdn.sofifa.net/flags/be.png                      RF
# 4      https://cdn.sofifa.net/flags/fr.png                      ST
# 5                                        -                       -
# 6      https://cdn.sofifa.net/flags/be.png                      GK
# ...                                    ...                     ...
# 18524  https://cdn.sofifa.net/flags/ro.png                       -
# 18525  https://cdn.sofifa.net/flags/ca.png                       -
# 18530                                    -                       -
# 18532                                    -                       -
# 18535                                    -                       -
#
#       National Team Jersey Number  Attacking Work Rate  Defensive Work Rate  \
# 0                              10                  Low                  Low
# 3                               7                 High                 High
# 4                              10                 High                  Low
# 5                               -                 High               Medium
# 6                               1               Medium               Medium
# ...                           ...                  ...                  ...
# 18524                           -               Medium               Medium
# 18525                           -               Medium               Medium
# 18530                           -               Medium               Medium
# 18532                           -               Medium                  Low
# 18535                           -               Medium               Medium
#
#       player_classification random_var
# 0             Top Performer   0.339556
# 3             Top Performer   0.199590
# 4             Top Performer   0.261127
# 5             Top Performer   0.130234
# 6             Top Performer   0.125950
# ...                     ...        ...
# 18524         Top Performer   0.003406
# 18525         Top Performer   0.092579
# 18530         Top Performer   0.356917
# 18532         Top Performer   0.310262
# 18535         Top Performer   0.037532
#
# [7424 rows x 35 columns]
#        Unnamed: 0           Known As                     Full Name  Overall  \
# 1               1         K. Benzema                 Karim Benzema       91
# 2               2     R. Lewandowski            Robert Lewandowski       91
# 8               8  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro       90
# 9               9        V. van Dijk               Virgil van Dijk       90
# 10             10            H. Kane                    Harry Kane       89
# ...           ...                ...                           ...      ...
# 18533       18533          Pi Ziyang                     Ziyang Pi       47
# 18534       18534         D. Collins                Darren Collins       47
# 18536       18536          L. Mullan                   Liam Mullan       47
# 18537       18537       D. McCallion              Daithí McCallion       47
# 18538       18538           N. Rabha                   Nabin Rabha       47
#
#        Potential  Value(in Euro) Positions Played Best Position  \
# 1             91        64000000            CF,ST            CF
# 2             91        84000000               ST            ST
# 8             90        41000000               ST            ST
# 9             90        98000000               CB            CB
# 10            89       105500000               ST            ST
# ...          ...             ...              ...           ...
# 18533         60          110000               CM           CAM
# 18534         56          110000            ST,RM           CAM
# 18536         67          130000               CM            RM
# 18537         61          100000               CB            CB
# 18538         50           60000               LB            LB
#
#                Nationality                                        Image Link  \
# 1                   France  https://cdn.sofifa.net/players/165/153/23_60.png
# 2                   Poland  https://cdn.sofifa.net/players/188/545/23_60.png
# 8                 Portugal  https://cdn.sofifa.net/players/020/801/23_60.png
# 9              Netherlands  https://cdn.sofifa.net/players/203/376/23_60.png
# 10                 England  https://cdn.sofifa.net/players/202/126/23_60.png
# ...                    ...                                               ...
# 18533             China PR  https://cdn.sofifa.net/players/269/066/23_60.png
# 18534  Republic of Ireland  https://cdn.sofifa.net/players/243/725/23_60.png
# 18536     Northern Ireland  https://cdn.sofifa.net/players/267/823/23_60.png
# 18537  Republic of Ireland  https://cdn.sofifa.net/players/267/824/23_60.png
# 18538                India  https://cdn.sofifa.net/players/261/424/23_60.png
#
#        ...  Skill Moves  International Reputation  National Team Name  \
# 1      ...            4                         4              France
# 2      ...            4                         5              Poland
# 8      ...            5                         5            Portugal
# 9      ...            2                         4         Netherlands
# 10     ...            3                         4             England
# ...    ...          ...                       ...                 ...
# 18533  ...            2                         1                   -
# 18534  ...            2                         1                   -
# 18536  ...            2                         1                   -
# 18537  ...            2                         1                   -
# 18538  ...            2                         1                   -
#
#                       National Team Image Link  National Team Position  \
# 1          https://cdn.sofifa.net/flags/fr.png                      ST
# 2          https://cdn.sofifa.net/flags/pl.png                      ST
# 8          https://cdn.sofifa.net/flags/pt.png                      ST
# 9          https://cdn.sofifa.net/flags/nl.png                      CB
# 10     https://cdn.sofifa.net/flags/gb-eng.png                      ST
# ...                                        ...                     ...
# 18533                                        -                       -
# 18534                                        -                       -
# 18536                                        -                       -
# 18537                                        -                       -
# 18538                                        -                       -
#
#       National Team Jersey Number  Attacking Work Rate  Defensive Work Rate  \
# 1                              19               Medium               Medium
# 2                               9                 High               Medium
# 8                               7                 High                  Low
# 9                               4               Medium                 High
# 10                              9                 High                 High
# ...                           ...                  ...                  ...
# 18533                           -               Medium               Medium
# 18534                           -               Medium               Medium
# 18536                           -                 High               Medium
# 18537                           -               Medium               Medium
# 18538                           -               Medium               Medium
#
#       player_classification random_var
# 1             Top Performer   0.844175
# 2             Top Performer   0.793340
# 8             Top Performer   0.827191
# 9             Top Performer   0.740856
# 10            Top Performer   0.975627
# ...                     ...        ...
# 18533         Top Performer   0.882392
# 18534         Top Performer   0.853053
# 18536         Top Performer   0.671725
# 18537         Top Performer   0.589491
# 18538         Top Performer   0.687691
#
# [11115 rows x 35 columns]

# %% [markdown]
# <font size = "5">
#
# (f) Create two overlapping scatter plots
#
# <font size = "3">
#
# - This question requires the two datasets you created in (e)
# - Display a scatter plot of "Potential" vs "Age" for "data0" using <br>
# ```plt.scatter()```
# - Display a scatter plot of "Potential" vs "Age" for "data1" overlapping <br>
# on top of the previous one
# - You will need to add a legend, label the axes, and the title
# - To get full points, plot the scatter plot with the option  ```alpha = 0.5```, e.g. <br>
#  ``` plt.hist(x = ..., y = ... , alpha = 0.5) ``` <br>
#  Make sure to substitute the corresponding "x" and "y" vectors instead of ```...``` <br>
# (The alpha option sets the transparency of the scatter plot)
#
# Note: The goal of this question is to illustrate that random <br>
# assignment will produce very similar scatter plots for each variable

# %%
# Write your own code

plt.scatter(x=data0["Age"], y=data0["Potential"], alpha=0.5, label="data0", color="blue")
plt.scatter(x=data1["Age"], y=data1["Potential"], alpha=0.5, label="data1", color="pink")

plt.xlabel("Age")
plt.ylabel("Potential")
plt.title("Scatter Plot of Potential VS. Age")

plt.legend()
plt.show()
