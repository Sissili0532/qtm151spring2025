# %% [markdown]
# # Assignment 6

# %% [markdown]
# ## Try to submit as an HTML file

# %% [markdown]
# <font size = "5">
# Print your Emory code below

# %%
print(2608780)
# Out:
# 2608780

# %% [markdown]
# <font size = "5">
#
# Import the "pandas" and "matplotlib.pyplot" libraries

# %%
# Write your answer here:
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.formula.api as smf

# %% [markdown]
# <font size = "5">
#
# (a) Functions
#
# <font size = "3">
#
# - Read the dataset labelled features.csv.
# - Create a ``` lambda ``` function that checks if displacement $>$ 200
# - Create a new list that shows true if displacement $>$ 200 and false <br>
# if displacement $\leq$ 200.
# - Count how many cars have displacement $> 200$.
#
# To get full credit use either the apply or the map function <br>
# (see Lectures 7 and 8)

# %%
# Write your answer here:

df = pd.read_csv("data/features.csv")

fn_displacement= lambda dispalcement: dispalcement > 200

df["displacement_list"] = list(map(fn_displacement,df["displacement"]))
car_number = df["displacement_list"].sum()

print(car_number)
# Out:
# 158

# %% [markdown]
# <font size = "5">
#
# (b) Subsetting Data
#
# <font size = "3" >
#
# - Read the dataset labelled features.csv.
# - Define a global variable called ```threshold``` that takes the <br>
# value 2588
# - Subset the data to get one dataset with weight $>$ threshold and <br>
# another with weight $\le$ 2588. Use the ```.query()``` function.
# - Compute the mean acceleration for each of these datasets.<br>
#
# Note: Review how to define a gloabl variable inside ```.query()```

# %%
# Write your answer here:

df = pd.read_csv("data/features.csv")

threshold = 2588

subset1 = df.query("weight > @threshold")
subset2 = df.query("weight <= @threshold")

average1 = np.mean(subset1["acceleration"])
average2 = np.mean(subset2["acceleration"])

print(average1)
print(average2)
# Out:
# 14.972457627118644
# 16.435802469135798

# %% [markdown]
# <font size = "5">
#
# (c) Use sorting + ".iloc[]"
#
# <font size = "3">
#
# - Read the "fifa23_players_basic.csv" dataset
# - Use ".sort_values()" to order the "Age" column <br>
# from youngest to oldest
# - Get a subset with the 5 youngest players

# %%
# Write your answer here:

df_1 = pd.read_csv("data/fifa23_players_basic.csv")

age_sorted = df_1.sort_values(by = "Age", ascending = True)

age_sorted.iloc[:5]
# Out:
#             Known As        Full Name  Overall  Potential  Value(in Euro)  \
# 17956     A. Dithmer  Andreas Dithmer       53         76          275000
# 18014      J. Ardila      José Ardila       53         73          250000
# 16084       S. Ngoma      Serge Ngoma       58         82          650000
# 11481      O. Vargas      Obed Vargas       64         81         1500000
# 17591  A. Madaliński  Alan Madaliński       54         68          210000
#
#       Positions Played Best Position    Nationality  \
# 17956               GK            GK        Denmark
# 18014               CM           CAM      Venezuela
# 16084               RW            RM  United States
# 11481        CM,CDM,RM           CAM  United States
# 17591               GK            GK         Poland
#
#                                              Image Link  Age  ...  \
# 17956  https://cdn.sofifa.net/players/269/573/23_60.png   16  ...
# 18014  https://cdn.sofifa.net/players/268/892/23_60.png   16  ...
# ...

# %% [markdown]
# <font size = "5">
#
# (d) Use queries + global variables
#
# <font size = "3">
#
# - Read the "fifa23_players_basic.csv" dataset
# - Compute the mean of the column "Wage(in Euro)" <br>
# and store it as a variable
# - Subset the players whose value is above the mean value <br>
#   using ".query()"
#
#
# HINT: Remember that there is a special syntax for <br>
# when the column names have spaces (see Lecture 10) <br>
# Reference the column as ``` `Wage(in Euro)`    ``` inside .query()

# %%
# Write your answer here:

df_1 = pd.read_csv("data/fifa23_players_basic.csv")
mean = df_1['Value(in Euro)'].mean()
print(mean)

Players_above_mean = df_1.query('`Value(in Euro)` > @mean')
print(Players_above_mean)
# Out:
# 2875461.4033658775
#             Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0           L. Messi        Lionel Messi       91         91        54000000
# 1         K. Benzema       Karim Benzema       91         91        64000000
# 2     R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3       K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4          K. Mbappé       Kylian Mbappé       91         95       190500000
# ...              ...                 ...      ...        ...             ...
# 7066       F. Rieder       Fabian Rieder       68         83         2900000
# 7071     J. Bakayoko      Johan Bakayoko       68         85         3100000
# 7090        M. Arezo        Matías Arezo       68         81         2900000
# 7096       Y. Kallon        Yayah Kallon       68         82         3000000
# 7168        M. Soulé        Matías Soulé       68         85         3100000
#
# ...

# %% [markdown]
# <font size = "5">
#
# (e) Plot by Category
#
# <font size = "3">
#
# Read the "data/wdi_urban.csv" dataset.
#
#   This contains data from 1980 and 2020.
#
# - **Create a list with the unique values of "year"**
#
# - **Create a plot with a ...**
#     - Histogram of "prop_urbanpopulation" for each year
#     - Set the histogram option `alpha = 0.5` for transparency
#     - All the histograms should be overlapping
#     - Create a legend with the list of years
#     - Label the axes and the title

# %%
# Write your answer here:

df_2 = pd.read_csv("data/wdi_urban.csv")

unique_years = df_2["year"].unique()

plt.figure(figsize=(10, 6))

for year in unique_years:
    subset = df_2[df_2["year"] == year]["prop_urbanpopulation"]
    plt.hist(subset, bins=20, alpha=0.5, label=str(year))

plt.xlabel("Proportion of Urban Population")
plt.ylabel("Frequency")
plt.title("Histogram of Urban Population Proportion (1980 & 2020)")
plt.legend(title="Year")

plt.show()
